# %%
import pandas as pd

ratings = pd.read_csv('/home/supay/datos/rating.csv')
ratings = ratings[['user_id','anime_id','rating']]
movies = pd.read_csv('/home/supay/datos/anime.csv')
movies = movies[['anime_id','name']]
movies = movies.head(700)

ratings = ratings.head(1000000)
ratings = pd.merge(movies, ratings)

#dif = ratings.anime_id.unique()
#print(len(dif))

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['name'],values='rating')

# %%
corrMatrix = userRatings.corr()
corrMatrix.head()
# Out:
# name                                   91 Days  Akachan to Boku  \
# name
# 91 Days                               1.000000              NaN
# Akachan to Boku                            NaN         1.000000
# Akagami no Shirayuki-hime             0.777608         0.819120
# Akagami no Shirayuki-hime 2nd Season  0.803738         0.842362
# Akatsuki no Yona                      0.802558         0.929712
#
# name                                  Akagami no Shirayuki-hime  \
# name
# 91 Days                                                0.777608
# Akachan to Boku                                        0.819120
# Akagami no Shirayuki-hime                              1.000000
# Akagami no Shirayuki-hime 2nd Season                   0.838401
# Akatsuki no Yona                                       0.784669
#
# name                                  Akagami no Shirayuki-hime 2nd Season  \
# name
# 91 Days                                                           0.803738
# Akachan to Boku                                                   0.842362
# Akagami no Shirayuki-hime                                         0.838401
# Akagami no Shirayuki-hime 2nd Season                              1.000000
# Akatsuki no Yona                                                  0.761829
#
# name                                  Akatsuki no Yona     Akira  \
# name
# 91 Days                                       0.802558  0.751373
# Akachan to Boku                               0.929712  0.500000
# Akagami no Shirayuki-hime                     0.784669  0.535952
# Akagami no Shirayuki-hime 2nd Season          0.761829  0.733831
# Akatsuki no Yona                              1.000000  0.653198
#
# name                                  Angel Beats!  \
# name
# 91 Days                                   0.584604
# Akachan to Boku                           0.970350
# Akagami no Shirayuki-hime                 0.665469
# Akagami no Shirayuki-hime 2nd Season      0.753638
# Akatsuki no Yona                          0.709865
#
# name                                  Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.  \
# name
# 91 Days                                                                        0.614450
# Akachan to Boku                                                                0.982918
# Akagami no Shirayuki-hime                                                      0.696524
# Akagami no Shirayuki-hime 2nd Season                                           0.747253
# Akatsuki no Yona                                                               0.754045
#
# name                                  Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai. Movie  \
# name
# 91 Days                                                                        0.700865
# Akachan to Boku                                                                0.956686
# Akagami no Shirayuki-hime                                                      0.615987
# Akagami no Shirayuki-hime 2nd Season                                           0.922817
# Akatsuki no Yona                                                               0.731016
#
# name                                  Ansatsu Kyoushitsu (TV)  ...  \
# name                                                           ...
# 91 Days                                              0.737688  ...
# Akachan to Boku                                      0.886479  ...
# Akagami no Shirayuki-hime                            0.811076  ...
# Akagami no Shirayuki-hime 2nd Season                 0.834238  ...
# Akatsuki no Yona                                     0.834930  ...
#
# name                                  Zetsuen no Tempest  \
# name
# 91 Days                                         0.683039
# Akachan to Boku                                 0.964798
# Akagami no Shirayuki-hime                       0.723016
# Akagami no Shirayuki-hime 2nd Season            0.745579
# Akatsuki no Yona                                0.755905
#
# name                                  Zoku Natsume Yuujinchou  \
# name
# 91 Days                                              0.575104
# Akachan to Boku                                      0.959099
# Akagami no Shirayuki-hime                            0.717627
# Akagami no Shirayuki-hime 2nd Season                 0.859184
# Akatsuki no Yona                                     0.782423
#
# name                                  Zoku Sayonara Zetsubou Sensei  \
# name
# 91 Days                                                    0.235751
# Akachan to Boku                                                 NaN
# Akagami no Shirayuki-hime                                  0.668181
# Akagami no Shirayuki-hime 2nd Season                       0.658677
# Akatsuki no Yona                                           0.620855
#
# name                                  ef: A Tale of Melodies.  \
# name
# 91 Days                                              0.526945
# Akachan to Boku                                           NaN
# Akagami no Shirayuki-hime                            0.751844
# Akagami no Shirayuki-hime 2nd Season                 0.706332
# Akatsuki no Yona                                     0.728292
#
# name                                  ef: A Tale of Memories.  xxxHOLiC  \
# name
# 91 Days                                              0.631376  0.162057
# Akachan to Boku                                           NaN       NaN
# Akagami no Shirayuki-hime                            0.511694  0.480416
# Akagami no Shirayuki-hime 2nd Season                 0.487258  0.261125
# Akatsuki no Yona                                     0.604018  0.544789
#
# name                                  xxxHOLiC Kei  \
# name
# 91 Days                                   0.341870
# Akachan to Boku                                NaN
# Akagami no Shirayuki-hime                 0.567449
# Akagami no Shirayuki-hime 2nd Season      0.333878
# Akatsuki no Yona                          0.636937
#
# name                                  xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# 91 Days                                                              0.997271
# Akachan to Boku                                                     -1.000000
# Akagami no Shirayuki-hime                                            0.771708
# Akagami no Shirayuki-hime 2nd Season                                 0.546192
# Akatsuki no Yona                                                     0.677709
#
# name                                  xxxHOLiC Rou  xxxHOLiC Shunmuki
# name
# 91 Days                                   0.382979           0.529281
# Akachan to Boku                          -1.000000                NaN
# Akagami no Shirayuki-hime                 0.674905           0.725756
# Akagami no Shirayuki-hime 2nd Season      0.695826           0.465557
# Akatsuki no Yona                          0.652311           0.695865
#
# [5 rows x 680 columns]

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=5)
corrMatrix.head()
# Out:
# name                                   91 Days  Akachan to Boku  \
# name
# 91 Days                               1.000000              NaN
# Akachan to Boku                            NaN         1.000000
# Akagami no Shirayuki-hime             0.777608         0.819120
# Akagami no Shirayuki-hime 2nd Season  0.803738              NaN
# Akatsuki no Yona                      0.802558         0.929712
#
# name                                  Akagami no Shirayuki-hime  \
# name
# 91 Days                                                0.777608
# Akachan to Boku                                        0.819120
# Akagami no Shirayuki-hime                              1.000000
# Akagami no Shirayuki-hime 2nd Season                   0.838401
# Akatsuki no Yona                                       0.784669
#
# name                                  Akagami no Shirayuki-hime 2nd Season  \
# name
# 91 Days                                                           0.803738
# Akachan to Boku                                                        NaN
# Akagami no Shirayuki-hime                                         0.838401
# Akagami no Shirayuki-hime 2nd Season                              1.000000
# Akatsuki no Yona                                                  0.761829
#
# name                                  Akatsuki no Yona     Akira  \
# name
# 91 Days                                       0.802558  0.751373
# Akachan to Boku                               0.929712       NaN
# Akagami no Shirayuki-hime                     0.784669  0.535952
# Akagami no Shirayuki-hime 2nd Season          0.761829  0.733831
# Akatsuki no Yona                              1.000000  0.653198
#
# name                                  Angel Beats!  \
# name
# 91 Days                                   0.584604
# Akachan to Boku                           0.970350
# Akagami no Shirayuki-hime                 0.665469
# Akagami no Shirayuki-hime 2nd Season      0.753638
# Akatsuki no Yona                          0.709865
#
# name                                  Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.  \
# name
# 91 Days                                                                        0.614450
# Akachan to Boku                                                                0.982918
# Akagami no Shirayuki-hime                                                      0.696524
# Akagami no Shirayuki-hime 2nd Season                                           0.747253
# Akatsuki no Yona                                                               0.754045
#
# name                                  Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai. Movie  \
# name
# 91 Days                                                                        0.700865
# Akachan to Boku                                                                     NaN
# Akagami no Shirayuki-hime                                                      0.615987
# Akagami no Shirayuki-hime 2nd Season                                           0.922817
# Akatsuki no Yona                                                               0.731016
#
# name                                  Ansatsu Kyoushitsu (TV)  ...  \
# name                                                           ...
# 91 Days                                              0.737688  ...
# Akachan to Boku                                      0.886479  ...
# Akagami no Shirayuki-hime                            0.811076  ...
# Akagami no Shirayuki-hime 2nd Season                 0.834238  ...
# Akatsuki no Yona                                     0.834930  ...
#
# name                                  Zetsuen no Tempest  \
# name
# 91 Days                                         0.683039
# Akachan to Boku                                 0.964798
# Akagami no Shirayuki-hime                       0.723016
# Akagami no Shirayuki-hime 2nd Season            0.745579
# Akatsuki no Yona                                0.755905
#
# name                                  Zoku Natsume Yuujinchou  \
# name
# 91 Days                                              0.575104
# Akachan to Boku                                      0.959099
# Akagami no Shirayuki-hime                            0.717627
# Akagami no Shirayuki-hime 2nd Season                 0.859184
# Akatsuki no Yona                                     0.782423
#
# name                                  Zoku Sayonara Zetsubou Sensei  \
# name
# 91 Days                                                    0.235751
# Akachan to Boku                                                 NaN
# Akagami no Shirayuki-hime                                  0.668181
# Akagami no Shirayuki-hime 2nd Season                       0.658677
# Akatsuki no Yona                                           0.620855
#
# name                                  ef: A Tale of Melodies.  \
# name
# 91 Days                                              0.526945
# Akachan to Boku                                           NaN
# Akagami no Shirayuki-hime                            0.751844
# Akagami no Shirayuki-hime 2nd Season                 0.706332
# Akatsuki no Yona                                     0.728292
#
# name                                  ef: A Tale of Memories.  xxxHOLiC  \
# name
# 91 Days                                              0.631376  0.162057
# Akachan to Boku                                           NaN       NaN
# Akagami no Shirayuki-hime                            0.511694  0.480416
# Akagami no Shirayuki-hime 2nd Season                 0.487258  0.261125
# Akatsuki no Yona                                     0.604018  0.544789
#
# name                                  xxxHOLiC Kei  \
# name
# 91 Days                                   0.341870
# Akachan to Boku                                NaN
# Akagami no Shirayuki-hime                 0.567449
# Akagami no Shirayuki-hime 2nd Season      0.333878
# Akatsuki no Yona                          0.636937
#
# name                                  xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# 91 Days                                                              0.997271
# Akachan to Boku                                                           NaN
# Akagami no Shirayuki-hime                                            0.771708
# Akagami no Shirayuki-hime 2nd Season                                 0.546192
# Akatsuki no Yona                                                     0.677709
#
# name                                  xxxHOLiC Rou  xxxHOLiC Shunmuki
# name
# 91 Days                                   0.382979           0.529281
# Akachan to Boku                                NaN                NaN
# Akagami no Shirayuki-hime                 0.674905           0.725756
# Akagami no Shirayuki-hime 2nd Season      0.695826           0.465557
# Akatsuki no Yona                          0.652311           0.695865
#
# [5 rows x 680 columns]

# %%
anime = input("Introducir id del anime")
calificacion = int(input("Introducir calificacion: "))
# Out:
# Introducir id del anime91 Days
# Introducir calificacion: 5

# %%
simCandidates = pd.Series()
#print(simCandidates)
# Recuperar las pelis similares a las calificadas
sims = corrMatrix[anime].dropna()
# Escalar la similaridad multiplicando por la calificación de la persona
sims = sims.map(lambda x: x * calificacion)
# Añadir el puntaje a la lista de candidatos similares
simCandidates = simCandidates.append(sims)
    
#Mirar los resultados:
#print ("ordenando...")
simCandidates.sort_values(inplace = True, ascending = False)
print (simCandidates.head(10))
# Out:
# 91 Days                                       5.000000
# xxxHOLiC Movie: Manatsu no Yoru no Yume       4.986357
# Kyou kara Maou! 3rd Series                    4.986059
# Saint Seiya: Meiou Hades Meikai-hen           4.980518
# Aria The OVA: Arietta                         4.970238
# Princess Tutu                                 4.969037
# Saint Seiya: Meiou Hades Juuni Kyuu-hen       4.967845
# Detective Conan OVA 10: Kid in Trap Island    4.962305
# Doukyuusei (Movie)                            4.942335
# Hetalia: The Beautiful World                  4.924581
# dtype: float64
# <ipython-input-16-c8a2af564ddd>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   simCandidates = pd.Series()

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.sort_values(inplace = True, ascending = False)
simCandidates.head(10)
# Out:
# 91 Days                                       5.000000
# xxxHOLiC Movie: Manatsu no Yoru no Yume       4.986357
# Kyou kara Maou! 3rd Series                    4.986059
# Saint Seiya: Meiou Hades Meikai-hen           4.980518
# Aria The OVA: Arietta                         4.970238
# Princess Tutu                                 4.969037
# Saint Seiya: Meiou Hades Juuni Kyuu-hen       4.967845
# Detective Conan OVA 10: Kid in Trap Island    4.962305
# Doukyuusei (Movie)                            4.942335
# Hetalia: The Beautiful World                  4.924581
# dtype: float64

# %%
#print(myRatings)
filteredSims = simCandidates.drop(anime,errors='ignore')
filteredSims.head()
# Out:
# xxxHOLiC Movie: Manatsu no Yoru no Yume    4.986357
# Kyou kara Maou! 3rd Series                 4.986059
# Saint Seiya: Meiou Hades Meikai-hen        4.980518
# Aria The OVA: Arietta                      4.970238
# Princess Tutu                              4.969037
# dtype: float64

# %%
lista = filteredSims.keys()
lista
# Out:
# Index(['xxxHOLiC Movie: Manatsu no Yoru no Yume', 'Kyou kara Maou! 3rd Series',
#        'Saint Seiya: Meiou Hades Meikai-hen', 'Aria The OVA: Arietta',
#        'Princess Tutu', 'Saint Seiya: Meiou Hades Juuni Kyuu-hen',
#        'Detective Conan OVA 10: Kid in Trap Island', 'Doukyuusei (Movie)',
#        'Hetalia: The Beautiful World',
#        'Kino no Tabi: Nanika wo Suru Tame ni - Life Goes On.',
#        ...
#        'Shoujo Kakumei Utena', 'Aria The Origination',
#        'Aria The Origination: Sono Choppiri Himitsu no Basho ni...',
#        'Mononoke',
#        'Ghost in the Shell: Stand Alone Complex - The Laughing Man',
#        'Tsumiki no Ie',
#        'Yahari Ore no Seishun Love Comedy wa Machigatteiru. Zoku OVA',
#        'Kaguya-hime no Monogatari', 'Kuuchuu Buranko', 'Major: World Series'],
#       dtype='object', length=580)
