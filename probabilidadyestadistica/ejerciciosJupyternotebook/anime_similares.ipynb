# %%
import pandas as pd

ratings = pd.read_csv('/home/supay/datos/rating.csv')
ratings = ratings[['user_id','anime_id','rating']]
movies = pd.read_csv('/home/supay/datos/anime.csv')
movies = movies[['anime_id','name']]

ratings = ratings.head(2000000)
ratings = pd.merge(movies, ratings)

dif = ratings.anime_id.unique()
print(len(dif))

#ratings.tail(100)
# Out:
# 9267

# %%
animesRatings = ratings.pivot_table(index=['user_id'],columns=['name'],values='rating')

animesRatings
#print(animesRatings.keys())
# Out:
# name     &quot;0&quot;  &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# 5                  NaN                                                NaN
# ...                ...                                                ...
# 19380              NaN                                                NaN
# 19381              NaN                                                NaN
# 19382              NaN                                                NaN
# 19383              NaN                                                NaN
# 19384              NaN                                                NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
# 5                                       NaN                               NaN
# ...                                     ...                               ...
# 19380                                   NaN                               NaN
# 19381                                   NaN                               NaN
# 19382                                   NaN                               NaN
# 19383                                   NaN                               NaN
# 19384                                   NaN                               NaN
#
# name     &quot;Eiji&quot;  .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                     NaN                   NaN                  NaN
# 2                     NaN                   NaN                  NaN
# 3                     NaN                   NaN                  NaN
# 4                     NaN                   NaN                  NaN
# 5                     NaN                   NaN                  NaN
# ...                   ...                   ...                  ...
# 19380                 NaN                   NaN                  NaN
# 19381                 NaN                   NaN                  NaN
# 19382                 NaN                   NaN                  NaN
# 19383                 NaN                   NaN                  NaN
# 19384                 NaN                   NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 1                                     NaN          NaN                NaN
# 2                                     NaN          NaN                NaN
# 3                                     NaN          NaN                NaN
# 4                                     NaN          NaN                NaN
# 5                                     NaN          NaN                NaN
# ...                                   ...          ...                ...
# 19380                                 NaN          NaN                NaN
# 19381                                 NaN          NaN                NaN
# 19382                                 NaN          NaN                NaN
# 19383                                 NaN          NaN                NaN
# 19384                                 NaN          NaN                NaN
#
# name     ...  lilac (bombs Jun Togawa)  makemagic  s.CRY.ed  vivi  xxxHOLiC  \
# user_id  ...
# 1        ...                       NaN        NaN       NaN   NaN       NaN
# 2        ...                       NaN        NaN       NaN   NaN       NaN
# 3        ...                       NaN        NaN       NaN   NaN       NaN
# 4        ...                       NaN        NaN       NaN   NaN       NaN
# 5        ...                       NaN        NaN       NaN   NaN       2.0
# ...      ...                       ...        ...       ...   ...       ...
# 19380    ...                       NaN        NaN       NaN   NaN       NaN
# 19381    ...                       NaN        NaN       NaN   NaN       7.0
# 19382    ...                       NaN        NaN       NaN   NaN       NaN
# 19383    ...                       NaN        NaN       NaN   NaN      10.0
# 19384    ...                       NaN        NaN       NaN   NaN       NaN
#
# name     xxxHOLiC Kei  xxxHOLiC Movie: Manatsu no Yoru no Yume  xxxHOLiC Rou  \
# user_id
# 1                 NaN                                      NaN           NaN
# 2                 NaN                                      NaN           NaN
# 3                 NaN                                      NaN           NaN
# 4                 NaN                                      NaN           NaN
# 5                 NaN                                      NaN           NaN
# ...               ...                                      ...           ...
# 19380             NaN                                      NaN           NaN
# 19381             NaN                                      NaN           NaN
# 19382             NaN                                      NaN           NaN
# 19383             NaN                                      NaN           NaN
# 19384             NaN                                      NaN           NaN
#
# name     xxxHOLiC Shunmuki   ◯
# user_id
# 1                      NaN NaN
# 2                      NaN NaN
# 3                      NaN NaN
# 4                      NaN NaN
# 5                      NaN NaN
# ...                    ...  ..
# 19380                  NaN NaN
# 19381                  NaN NaN
# 19382                  NaN NaN
# 19383                  NaN NaN
# 19384                  NaN NaN
#
# [19384 rows x 9267 columns]

# %%
animeRatings = animesRatings['Ansatsu Kyoushitsu (TV) 2nd Season']

# %%
similarMovies = animesRatings.corrwith(animeRatings)
similarMovies = similarMovies.dropna()

df = pd.DataFrame(similarMovies)
df.head(10)
# Out:
# /home/supay/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/supay/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                                            0
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.791640
# &quot;Bungaku Shoujo&quot; Memoire                  0.719206
# &quot;Bungaku Shoujo&quot; Movie                    0.746496
# .hack//G.U. Returner                                0.769199
# .hack//G.U. Trilogy                                 0.542531
# .hack//G.U. Trilogy: Parody Mode                    0.617945
# .hack//Gift                                         0.646538
# .hack//Intermezzo                                   0.823743
# .hack//Liminality                                   0.579049
# .hack//Quantum                                      0.225405
