# %%
import pandas as pd

books_ratings = pd.read_csv('/home/supay/Descargas/Book_Ratings.csv',sep = ';', encoding="ISO-8859-1")

books = pd.read_csv('/home/supay/Descargas/Books.csv',sep = ';', encoding="ISO-8859-1",error_bad_lines=False)
books = books[['ISBN','Book-Title']]

books_ratings = books_ratings.head(9000)

ratings = pd.merge(books, books_ratings)
# Out:
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# b'Skipping line 209388: expected 8 fields, saw 9\nSkipping line 220626: expected 8 fields, saw 9\nSkipping line 227933: expected 8 fields, saw 11\nSkipping line 228957: expected 8 fields, saw 10\nSkipping line 245933: expected 8 fields, saw 9\nSkipping line 251296: expected 8 fields, saw 9\nSkipping line 259941: expected 8 fields, saw 9\nSkipping line 261529: expected 8 fields, saw 9\n'
# ...

# %%
userRatings = ratings.pivot_table(index=['User-ID'],columns=['ISBN'],values='Book-Rating')

userRatings.head()
# Out:
# ISBN     0002240114  000225669X  0002558122  0006379702  0006485294  \
# User-ID
# 276725          NaN         NaN         NaN         NaN         NaN
# 276726          NaN         NaN         NaN         NaN         NaN
# 276727          NaN         NaN         NaN         NaN         NaN
# 276729          NaN         NaN         NaN         NaN         NaN
# 276733          NaN         NaN         NaN         NaN         NaN
#
# ISBN     0006542808  0006543545  0006546684  0006715184  0020198906  ...  \
# User-ID                                                              ...
# 276725          NaN         NaN         NaN         NaN         NaN  ...
# 276726          NaN         NaN         NaN         NaN         NaN  ...
# 276727          NaN         NaN         NaN         NaN         NaN  ...
# 276729          NaN         NaN         NaN         NaN         NaN  ...
# 276733          NaN         NaN         NaN         NaN         NaN  ...
#
# ...

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# ISBN        0002240114  000225669X  0002558122  0006379702  0006485294  \
# ISBN
# 0002240114         NaN         NaN         NaN         NaN         NaN
# 000225669X         NaN         NaN         NaN         NaN         NaN
# 0002558122         NaN         NaN         NaN         NaN         NaN
# 0006379702         NaN         NaN         NaN         NaN         NaN
# 0006485294         NaN         NaN         NaN         NaN         NaN
#
# ISBN        0006542808  0006543545  0006546684  0006715184  0020198906  ...  \
# ISBN                                                                    ...
# 0002240114         NaN         NaN         NaN         NaN         NaN  ...
# 000225669X         NaN         NaN         NaN         NaN         NaN  ...
# 0002558122         NaN         NaN         NaN         NaN         NaN  ...
# 0006379702         NaN         NaN         NaN         NaN         NaN  ...
# 0006485294         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
myRatings = userRatings.loc[276733].dropna()
myRatings
# Out:
# ISBN
# 2080674722    0.0
# Name: 276733, dtype: float64
